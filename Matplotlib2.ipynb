# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\abdul karrar\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: numpy>=1.23 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (23.0)
# Requirement already satisfied: pillow>=8 in c:\users\abdul karrar\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: six>=1.5 in c:\users\abdul karrar\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
import pandas as pd

# %%
months=["jan","feb","mar","apr","may","jun","jul","aug","sep","oct","nov","dec"]
sales=[11860,10480,4997,5523,13965,6011,13158,9533,5158,9058,11346,6675]
plt.bar(months,sales,color='skyblue',edgecolor='black')
plt.title('total sales for each month',fontsize=16)
plt.xlabel('month',fontsize=12)
plt.ylabel('total sales',fontsize=12)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.tight_layout()
plt.show()
